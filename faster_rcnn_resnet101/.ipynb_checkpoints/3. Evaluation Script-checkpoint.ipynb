# %% [markdown]
# # 7144COMP/CW2: Bird Multiple Object Detection Using Faster R-CNN ResNet101 Network
# ## PART III: Model evaluation and deployment
#
# ### Overview
#
# In this notebook, I will:
#
# - Run the necessary evaluation scripts
#
# ### Next
# In the next notebook which is an extension to the present, I will:
# - Launch TensorBoard displaying both the train and evaluation metrics for the given session.
# - Provide justification for the number of epochs used for training your object detection model
# - Freeze my trained model in correct format for model inferencing
# - Develop a Jupyter Notebook to perform inference on the frozen model using unseen test images
# - Discuss my results.
#
# ### Prerequisites
# This notebook runs locally on the environment *tf-gpu*.
# - Environment Setup (see Part 0)
# - Preprocessing (see Part 1)
# - Training (see Part 2)

# %% [markdown]
# ## 1. Import the necessary packages

# %%
import os

# %%
# Current directory
current_dir = os.getcwd()

# Model training directory and config pipeline
model_dir = os.path.join(current_dir, 'training') #<- the location of our train and eval folders
pipeline_config_path = 'fasterrcnn_config.config'

# %%
current_dir
# Out:
# '/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101'

# %% [markdown]
# ## 2. Run the evaluation script
#
# ```model_main_tf2.py``` (same used for training to create train logs) performs evaluation when some arguments are specified. The last checkpoint is loaded from the ```checkpoint_dir``` directory, to load the last state of the model, and use the model ```pipeline_config_path``` to create en eval folder inside the training folder containing the logs of evaluation.
#
# Later on, in the next notebook, we point ```logdir``` to the eval folder to plot eval metrics on TensorBoard.
#
# **DetectionBoxes_Precision:**
#
# - ```DetectionBoxes_Precision/mAP```: mean average precision over classes averaged over IoU thresholds ranging from ```.5``` to ```.95``` with ```.05``` increments.
# - ```DetectionBoxes_Precision/mAP@.50IOU```: mean average precision at 50% IoU
# - ```DetectionBoxes_Precision/mAP@.75IOU```: mean average precision at 75% IoU
# - ```DetectionBoxes_Precision/mAP (small)```: mean average precision for small objects (area < 32^2 pixels).
# - ```DetectionBoxes_Precision/mAP (medium)```: mean average precision for medium sized objects (32^2 pixels < area < 96^2 pixels).
# - ```DetectionBoxes_Precision/mAP (large)```: mean average precision for large objects (96^2 pixels < area < 10000^2 pixels).
#
# **DetectionBoxes_Recall**
#
# - ```DetectionBoxes_Recall/AR@1```: average recall with 1 detection.
# - ```DetectionBoxes_Recall/AR@10```: average recall with 10 detections.
# - ```DetectionBoxes_Recall/AR@100```: average recall with 100 detections.
# - ```DetectionBoxes_Recall/AR@100 (small)```: average recall for small objects with 100.
# - ```DetectionBoxes_Recall/AR@100 (medium)```: average recall for medium objects with 100.
# - ```DetectionBoxes_Recall/AR@100 (large)```: average recall for large objects with 100 detections.

# %% [markdown]
# Here we will display general performance metrics using ```coco_detection_metrics``` and per-class performance metrics using ```pascal_voc_detection_metrics```

# %% [markdown]
# ### Get evaluation metrics using ```coco_detection_metrics```
# Set ```metrics_set: "coco_detection_metrics"``` in ```fasterrcnn_pipeline.config``` before running the script below.

# %%
# Execute evaluation script
# This will create an **eval** folder inside the training folder
# !python $current_dir/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=$pipeline_config_path \
    --model_dir=$model_dir \
    --alsologtostderr \
    --checkpoint_dir=$model_dir \
    --sample_1_of_n_eval_examples=1
# Out:
# 2023-01-08 14:35:26.612360: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-08 14:35:27.998385: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2023-01-08 14:35:27.998461: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2023-01-08 14:35:27.998475: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-01-08 14:35:30.669380: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2023-01-08 14:35:30.669407: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: CMPR01
# 2023-01-08 14:35:30.669414: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: CMPR01
# 2023-01-08 14:35:30.669491: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.161.3
# 2023-01-08 14:35:30.669511: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.91.3
# 2023-01-08 14:35:30.669518: E tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 460.91.3 does not match DSO version 470.161.3 -- cannot find working devices in this configuration
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0108 14:35:30.671846 140565123168064 model_lib_v2.py:1089] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I0108 14:35:30.671971 140565123168064 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0108 14:35:30.672037 140565123168064 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0108 14:35:30.672092 140565123168064 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0108 14:35:30.672160 140565123168064 model_lib_v2.py:1106] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2023-01-08 14:35:30.696214: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Reading unweighted datasets: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/test/birds.tfrecord']
# I0108 14:35:30.760483 140565123168064 dataset_builder.py:162] Reading unweighted datasets: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/test/birds.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/test/birds.tfrecord']
# I0108 14:35:30.760833 140565123168064 dataset_builder.py:79] Reading record datasets for input file: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/test/birds.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0108 14:35:30.760950 140565123168064 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0108 14:35:30.761042 140565123168064 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0108 14:35:30.764548 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0108 14:35:30.791835 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0108 14:35:31.596364 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0108 14:35:35.855346 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0108 14:35:37.497032 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# I0108 14:35:40.923052 140565123168064 checkpoint_utils.py:140] Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# INFO:tensorflow:Found new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-22
# I0108 14:35:40.923912 140565123168064 checkpoint_utils.py:149] Found new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-22
# /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I0108 14:35:53.817630 140565123168064 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W0108 14:36:03.728435 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W0108 14:36:10.007465 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2023-01-08 14:36:26.273364: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 963379200 exceeds 10% of free system memory.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0108 14:36:26.969696 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0108 14:36:26.997445 140565123168064 model_lib_v2.py:966] Finished eval step 0
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0108 14:36:27.185345 140565123168064 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# 2023-01-08 14:36:27.822972: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 963379200 exceeds 10% of free system memory.
# 2023-01-08 14:36:29.226185: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 963379200 exceeds 10% of free system memory.
# 2023-01-08 14:36:30.589720: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 963379200 exceeds 10% of free system memory.
# 2023-01-08 14:36:31.968966: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 963379200 exceeds 10% of free system memory.
# INFO:tensorflow:Finished eval step 100
# I0108 14:38:21.690130 140565123168064 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0108 14:40:15.739005 140565123168064 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0108 14:42:08.679063 140565123168064 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Performing evaluation on 375 images.
# I0108 14:43:31.597296 140565123168064 coco_evaluation.py:293] Performing evaluation on 375 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0108 14:43:31.598926 140565123168064 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.06s)
# I0108 14:43:31.663501 140565123168064 coco_tools.py:138] DONE (t=0.06s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.28s).
# Accumulating evaluation results...
# DONE (t=1.55s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.543
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.873
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.609
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.141
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.382
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.266
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
# INFO:tensorflow:Eval metrics at step 21000
# I0108 14:43:36.698354 140565123168064 model_lib_v2.py:1015] Eval metrics at step 21000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.542959
# I0108 14:43:36.709749 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.542959
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.872923
# I0108 14:43:36.711172 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.872923
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.609314
# I0108 14:43:36.712348 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.609314
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.140773
# I0108 14:43:36.713349 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.140773
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.381631
# I0108 14:43:36.714054 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.381631
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.638725
# I0108 14:43:36.714852 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.638725
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.615586
# I0108 14:43:36.715602 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.615586
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.655601
# I0108 14:43:36.716326 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.655601
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.657790
# I0108 14:43:36.717002 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.657790
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.266250
# I0108 14:43:36.717646 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.266250
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.549975
# I0108 14:43:36.718212 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.549975
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.724373
# I0108 14:43:36.718907 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.724373
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.077939
# I0108 14:43:36.719478 140565123168064 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.077939
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.042339
# I0108 14:43:36.720235 140565123168064 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.042339
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.051218
# I0108 14:43:36.720801 140565123168064 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.051218
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.074959
# I0108 14:43:36.721456 140565123168064 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.074959
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I0108 14:43:36.722155 140565123168064 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.246456
# I0108 14:43:36.722840 140565123168064 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.246456
# INFO:tensorflow:Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# I0108 14:43:37.059121 140565123168064 checkpoint_utils.py:140] Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# INFO:tensorflow:Found new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# I0108 15:10:26.284198 140565123168064 checkpoint_utils.py:149] Found new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# INFO:tensorflow:Finished eval step 0
# I0108 15:10:33.824830 140565123168064 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0108 15:11:46.815527 140565123168064 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0108 15:12:58.381135 140565123168064 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0108 15:14:09.745859 140565123168064 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Performing evaluation on 375 images.
# I0108 15:15:02.092407 140565123168064 coco_evaluation.py:293] Performing evaluation on 375 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0108 15:15:02.093274 140565123168064 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.04s)
# I0108 15:15:02.131240 140565123168064 coco_tools.py:138] DONE (t=0.04s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.55s).
# Accumulating evaluation results...
# DONE (t=0.69s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.863
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.665
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.666
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.273
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
# INFO:tensorflow:Eval metrics at step 22000
# I0108 15:15:04.423770 140565123168064 model_lib_v2.py:1015] Eval metrics at step 22000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.560802
# I0108 15:15:04.427697 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.560802
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.862891
# I0108 15:15:04.428298 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.862891
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.634445
# I0108 15:15:04.428818 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.634445
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.172074
# I0108 15:15:04.429336 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.172074
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.387250
# I0108 15:15:04.429850 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.387250
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.649706
# I0108 15:15:04.430376 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.649706
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.622986
# I0108 15:15:04.430900 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.622986
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.664614
# I0108 15:15:04.431423 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.664614
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.666459
# I0108 15:15:04.432039 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.666459
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.272917
# I0108 15:15:04.432683 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.272917
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.549853
# I0108 15:15:04.433296 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.549853
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.734886
# I0108 15:15:04.433903 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.734886
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.070795
# I0108 15:15:04.434418 140565123168064 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.070795
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.046445
# I0108 15:15:04.434905 140565123168064 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.046445
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.051902
# I0108 15:15:04.435381 140565123168064 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.051902
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 0.078238
# I0108 15:15:04.435812 140565123168064 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 0.078238
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I0108 15:15:04.436243 140565123168064 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 0.247380
# I0108 15:15:04.436783 140565123168064 model_lib_v2.py:1018] 	+ Loss/total_loss: 0.247380
# INFO:tensorflow:Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# I0108 15:15:26.306160 140565123168064 checkpoint_utils.py:140] Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:21.169548 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:22.171142 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:23.172751 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:24.174331 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:25.175914 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:26.177486 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:27.179080 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:28.180675 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:29.182231 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:30.183804 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:31.184736 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:32.186298 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:33.187875 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:34.188753 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:35.190342 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:36.191923 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:37.193502 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:38.195081 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:39.196675 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:40.198248 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:41.199824 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:42.201395 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:43.203008 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:44.204604 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:45.206156 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:46.207719 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:47.209287 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:48.210849 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:49.212459 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:50.214037 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:51.215612 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:52.216740 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:53.218313 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:54.219905 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:55.221488 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:56.223650 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:57.224741 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:58.226325 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# ERROR:tensorflow:Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# E0108 15:37:59.227910 140565123168064 checkpoint_management.py:361] Couldn't match files for checkpoint /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-23
# INFO:tensorflow:Found new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-1
# I0108 15:38:00.228817 140565123168064 checkpoint_utils.py:149] Found new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training/ckpt-1
# INFO:tensorflow:Finished eval step 0
# I0108 15:38:07.436831 140565123168064 model_lib_v2.py:966] Finished eval step 0
# INFO:tensorflow:Finished eval step 100
# I0108 15:39:35.123209 140565123168064 model_lib_v2.py:966] Finished eval step 100
# INFO:tensorflow:Finished eval step 200
# I0108 15:41:23.083110 140565123168064 model_lib_v2.py:966] Finished eval step 200
# INFO:tensorflow:Finished eval step 300
# I0108 15:43:10.998771 140565123168064 model_lib_v2.py:966] Finished eval step 300
# INFO:tensorflow:Performing evaluation on 375 images.
# I0108 15:44:30.853891 140565123168064 coco_evaluation.py:293] Performing evaluation on 375 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0108 15:44:30.858894 140565123168064 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.11s)
# I0108 15:44:30.972822 140565123168064 coco_tools.py:138] DONE (t=0.11s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=3.17s).
# Accumulating evaluation results...
# DONE (t=1.69s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.003
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.014
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.033
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.053
# INFO:tensorflow:Eval metrics at step 0
# I0108 15:44:35.928124 140565123168064 model_lib_v2.py:1015] Eval metrics at step 0
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.000056
# I0108 15:44:35.932840 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP: 0.000056
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.000332
# I0108 15:44:35.933691 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.000332
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000001
# I0108 15:44:35.934310 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000001
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0108 15:44:35.934915 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): 0.000015
# I0108 15:44:35.935512 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (medium): 0.000015
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): 0.000097
# I0108 15:44:35.936113 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Precision/mAP (large): 0.000097
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.002970
# I0108 15:44:35.936725 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@1: 0.002970
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.013547
# I0108 15:44:35.937322 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@10: 0.013547
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.042908
# I0108 15:44:35.937925 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100: 0.042908
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0108 15:44:35.938481 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): 0.032990
# I0108 15:44:35.939081 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (medium): 0.032990
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): 0.053450
# I0108 15:44:35.939731 140565123168064 model_lib_v2.py:1018] 	+ DetectionBoxes_Recall/AR@100 (large): 0.053450
# INFO:tensorflow:	+ Loss/RPNLoss/localization_loss: 0.071396
# I0108 15:44:35.940221 140565123168064 model_lib_v2.py:1018] 	+ Loss/RPNLoss/localization_loss: 0.071396
# INFO:tensorflow:	+ Loss/RPNLoss/objectness_loss: 0.729793
# I0108 15:44:35.940742 140565123168064 model_lib_v2.py:1018] 	+ Loss/RPNLoss/objectness_loss: 0.729793
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/localization_loss: 0.014739
# I0108 15:44:35.941246 140565123168064 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/localization_loss: 0.014739
# INFO:tensorflow:	+ Loss/BoxClassifierLoss/classification_loss: 1.682986
# I0108 15:44:35.941751 140565123168064 model_lib_v2.py:1018] 	+ Loss/BoxClassifierLoss/classification_loss: 1.682986
# INFO:tensorflow:	+ Loss/regularization_loss: 0.000000
# I0108 15:44:35.942254 140565123168064 model_lib_v2.py:1018] 	+ Loss/regularization_loss: 0.000000
# INFO:tensorflow:	+ Loss/total_loss: 2.498914
# I0108 15:44:35.942757 140565123168064 model_lib_v2.py:1018] 	+ Loss/total_loss: 2.498914
# INFO:tensorflow:Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training
# I0108 15:44:36.134364 140565123168064 checkpoint_utils.py:140] Waiting for new checkpoint at /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training

# %% [markdown]
# ### Get per-class evaluation metrics using ```pascal_voc_detection_metrics```
# Set ```metrics_set: "pascal_voc_detection_metrics"``` in ```fasterrcnn_pipeline.config``` before running the script below.

# %%
# !python $current_dir/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=$pipeline_config_path \
    --model_dir=$model_dir \
    --alsologtostderr \
    --checkpoint_dir=$model_dir \
    --sample_1_of_n_eval_examples=1

# %% [markdown]
# ### Discussion
# The script above runs evaluation on a object detection model using ```TensorFlow 2```. The evaluation is performed using the configuration specified in the pipeline configuration file specified by ```--pipeline_config_path```. The model and checkpoints for the model are stored in the directory specified by ```--model_dir``` and ```--checkpoint_dir```, respectively.
#
# During evaluation, the script will use a single example from the evaluation dataset for each class for which there is at least one example of that class in the dataset. This is specified by the ```--sample_1_of_n_eval_examples``` flag, which is set to 1.

# %% [markdown]
# ### Next
# - Launch ```TensorBoard``` to display the train and evaluation metrics for the given session
