# %% [markdown]
# # 7144COMP/CW2: Bird Multiple Object Detection Using Faster R-CNN
# ## PART 2.Training
# ### Overview
# In this notebook, I will train an object detection model using the pre-processed data from the previous notebook.
#
# - Download the object detection models from Tensorflow 2 Detection Model Zoo >> [here](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md).
# - The model's hyperparameters and configuration are set in the ```fasterrcnn_config.config``` file.
# - The model is trained through this notebook using ```model_main_tf2.py``` with the relevent arguments.

# %% [markdown]
# #### Prerequisites
# - Environment Setup (see Part 0)
# - Data preprocessing (see Part 1)

# %% [markdown]
# ## 1. Download the model from TensorFlow 2 Detection Model Zoo
# #### Import the necessary packages

# %%
import os
import re #<- regular expressions
import tensorflow as tf
physical_devices = tf.config.list_physical_devices()
print("Num GPUs Available: ", len(physical_devices))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# #### Setup

# %%
# Define constants
# RANDOM_SEED ensure the reproduciblity of training results
RANDOM_SEED = 99
# We have 4,000 images and use a batch size of 1 
# an epoch consists of:
#36,00 images / (1 images / step) = 3600 steps.
BATCH_SIZE = 1
NUM_STEPS = 28000 
NUM_EVAL_STEPS = 1000

EPOCHS = 1
# Current directory
current_dir = os.getcwd()

# %% [markdown]
# #### Download Fine-tuned Faster R-CNN ResNet101 model

# %% [markdown]
# ***Why Faster R-CNN***?
#
# Faster R-CNN is an object detection model that improves on Fast R-CNN by utilising a region proposal network (RPN) with the CNN model.
#
# Faster R-CNN has impressive detection effects in ordinary scenes ([source](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7582940/)).
#
# However, under certain conditions, there can still be unsatisfactory detection performance, such as: the object having problems like occlusion, deformation, or small size ([source](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7582940/)).
#
# Our project deals with ordinary scenes, depending on the requirements, we should prioritise accuracy over speed, therefore, two-step object detectors like Faster R-CNN may be the most suitable for this task given the limitations in terms of time and computing power.

# %%
# Download Faster R-CNN ResNet101 if it doesn't exist locally
if not os.path.isdir('faster_rcnn_resnet101_v1_640x640_coco17_tpu-8'):
    # !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/faster_rcnn_resnet101_v1_640x640_coco17_tpu-8.tar.gz
    # Decompression and remove compressed files
    # !tar -xf faster_rcnn_resnet101_v1_640x640_coco17_tpu-8.tar.gz
    # Cleanup
    # !rm faster_rcnn_resnet101_v1_640x640_coco17_tpu-8.tar.gz

# %% [markdown]
# #### Load Train, Test, Valid TFRecords

# %%
# Train, Test, Valid TFRecord files
train_record_path = os.path.join(current_dir, 'Birds', 'train', 'birds.tfrecord')
test_record_path = os.path.join(current_dir, 'Birds', 'test', 'birds.tfrecord')
valid_record_path = os.path.join(current_dir, 'Birds', 'valid', 'birds.tfrecord')
# Labelmap
labelmap_path = os.path.join(current_dir, 'Birds', 'train', 'birds_label_map.pbtxt')

# %% [markdown]
# # 2. Model's Config files, Checkpoints and Hyperparameters

# %%
# Load the latest Checkpoint if it exists
# Default
fine_tune_checkpoint_fasterrcnn = 'faster_rcnn_resnet101_v1_640x640_coco17_tpu-8/checkpoint/ckpt-0'
#if os.path.isdir('training'):
    #fine_tune_checkpoint_fasterrcnn = os.path.join(current_dir, 'training')
print('Checkpoint Dir:', fine_tune_checkpoint_fasterrcnn)
# Out:
# Checkpoint Dir: faster_rcnn_resnet101_v1_640x640_coco17_tpu-8/checkpoint/ckpt-0

# %%
# config files can be edited and updated on ayoubbensakhria/TensorFlowOD repository
if os.path.isfile('pipeline.config'):
    # !rm 'pipeline.config'
# Download the latest base pipeline config file
# !wget https://raw.githubusercontent.com/ayoubbensakhria/TensorFlowOD/master/7144COMP/training/pipeline.config

# data_augmentation_options section has been removed because it has been done by Roboflow
base_config_path_fasterrcnn = 'pipeline.config'
# Out:
# --2022-12-21 22:33:01--  https://raw.githubusercontent.com/ayoubbensakhria/TensorFlowOD/master/7144COMP/training/pipeline.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3834 (3.7K) [text/plain]
# Saving to: ‘pipeline.config’
#
# pipeline.config     100%[===================>]   3.74K  --.-KB/s    in 0s
#
# 2022-12-21 22:33:01 (115 MB/s) - ‘pipeline.config’ saved [3834/3834]

# %% [markdown]
# #### Hyperparameters
#
# *num_epoch* = one forward pass and one backward pass of all the training examples. One step takes on average 2 seconds, an epoch consists of 28000 steps (batch_size=1), so the total duration of an epoch is approx 15 hours.
#
# *batch_size* = the number of training examples in one forward/backward pass (1 step). The higher the batch_size, the more memory space we would need. Here the available memory allows a max of batch_size = 1
#
# *num_steps*: number of iterations = number of passes, each pass using batch size number of 1
#
# Taking into consideration all the factors above, the following hyperparameters were set as follows:
#
# - ```batch_size: 1 ```
# - ```num_epochs: 1```
# - ```num_steps: 28000```
# - ```fixed_shape_resizer```: 640 px for height and width (resize input images) (refer to the preprocessing section for justification)

# %%
# Config Edition function
def edit_config(model_name, base_config_path, fine_tune_checkpoint):
  with open(base_config_path) as f:
    config = f.read()

  with open('{model}_config.config'.format(model=model_name), 'w') as f:

    # Set labelmap path
    config = re.sub('label_map_path: ".*£?"', 
              'label_map_path: "{}"'.format(labelmap_path), config)
    
    # Set min dimension
    config = re.sub('width: ".*?"', 
              'width: "{}"'.format(MIN_DIMENSION), config)
    
    # Set max dimension
    config = re.sub('height: ".*?"', 
              'height: "{}"'.format(MAX_DIMENSION), config)
    
    # Set fine_tune_checkpoint path
    config = re.sub('fine_tune_checkpoint: ".*?"',
                    'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), config)

    # Set train tf-record file path
    config = re.sub('(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 
                    'input_path: "{}"'.format(train_record_path), config)

    # Set test tf-record file path
    config = re.sub('(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 
                    'input_path: "{}"'.format(test_record_path), config)

    # Set number of classes.
    config = re.sub('num_classes: [0-9]+',
                    'num_classes: {}'.format(4), config)

    # Set batch size
    config = re.sub('batch_size: [0-9]+',
                    'batch_size: {}'.format(BATCH_SIZE), config)

    # Set training steps
    config = re.sub('num_steps: [0-9]+',
                    'num_steps: {}'.format(NUM_STEPS), config)

    # Set fine-tune checkpoint type to detection
    config = re.sub('fine_tune_checkpoint_type: "classification"', 
              'fine_tune_checkpoint_type: "{}"'.format('detection'), config)

    f.write(config)

# %%
# Edit config Fatser R-CNN
edit_config('fasterrcnn', base_config_path_fasterrcnn, fine_tune_checkpoint_fasterrcnn)
# Clean up
# !rm 'pipeline.config'
# Print config pipeline
# %cat 'fasterrcnn_config.config'
# Out:
# # Faster R-CNN with Resnet-101 (v1)
# # Trained on COCO, initialized from Imagenet classification checkpoint
#
# # This config is TPU compatible.
#
# model {
#   faster_rcnn {
#     num_classes: 4
#     image_resizer {
#       fixed_shape_resizer {
#         width: 640
#         height: 640
#       }
#     }
#     feature_extractor {
#       type: 'faster_rcnn_resnet101_keras'
#       batch_norm_trainable: true
#     }
#     first_stage_anchor_generator {
#       grid_anchor_generator {
#         scales: [0.25, 0.5, 1.0, 2.0]
#         aspect_ratios: [0.5, 1.0, 2.0]
#         height_stride: 16
#         width_stride: 16
#       }
#     }
#     first_stage_box_predictor_conv_hyperparams {
#       op: CONV
#       regularizer {
#         l2_regularizer {
#           weight: 0.0
#         }
#       }
#       initializer {
#         truncated_normal_initializer {
#           stddev: 0.01
#         }
#       }
#     }
#     first_stage_nms_score_threshold: 0.0
#     first_stage_nms_iou_threshold: 0.7
#     first_stage_max_proposals: 300
#     first_stage_localization_loss_weight: 2.0
#     first_stage_objectness_loss_weight: 1.0
#     initial_crop_size: 14
#     maxpool_kernel_size: 2
#     maxpool_stride: 2
#     second_stage_box_predictor {
#       mask_rcnn_box_predictor {
#         use_dropout: false
#         dropout_keep_probability: 1.0
#         fc_hyperparams {
#           op: FC
#           regularizer {
#             l2_regularizer {
#               weight: 0.0
#             }
#           }
#           initializer {
#             variance_scaling_initializer {
#               factor: 1.0
#               uniform: true
#               mode: FAN_AVG
#             }
#           }
#         }
#         share_box_across_classes: true
#       }
#     }
#     second_stage_post_processing {
#       batch_non_max_suppression {
#         score_threshold: 0.0
#         iou_threshold: 0.6
#         max_detections_per_class: 100
#         max_total_detections: 300
#       }
#       score_converter: SOFTMAX
#     }
#     second_stage_localization_loss_weight: 2.0
#     second_stage_classification_loss_weight: 1.0
#     use_static_shapes: true
#     use_matmul_crop_and_resize: true
#     clip_anchors_to_image: true
#     use_static_balanced_label_sampler: true
#     use_matmul_gather_in_matcher: true
#   }
# }
#
# train_config: {
#   batch_size: 1
#   sync_replicas: true
#   startup_delay_steps: 0
#   replicas_to_aggregate: 8
#   num_steps: 28000
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         cosine_decay_learning_rate {
#           learning_rate_base: .0004
#           total_steps: 100000
#           warmup_learning_rate: .00004
#           warmup_steps: 2000
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   fine_tune_checkpoint_version: V2
#   fine_tune_checkpoint: "faster_rcnn_resnet101_v1_640x640_coco17_tpu-8/checkpoint/ckpt-0"
#   fine_tune_checkpoint_type: "detection"
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#
#   data_augmentation_options {
#     random_adjust_hue {
#     }
#   }
#
#   data_augmentation_options {
#     random_adjust_contrast {
#     }
#   }
#
#   data_augmentation_options {
#     random_adjust_saturation {
#     }
#   }
#
#   data_augmentation_options {
#      random_square_crop_by_scale {
#       scale_min: 0.6
#       scale_max: 1.3
#     }
#   }
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
#   use_bfloat16: false  # works only on TPUs
# }
#
# train_input_reader: {
#   label_map_path: "/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds_label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds.tfrecord"
#   }
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
#   batch_size: 1;
# }
#
# eval_input_reader: {
#   label_map_path: "/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds_label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/test/birds.tfrecord"
#   }
# }

# %% [markdown]
# # 3. Train Faster R-CNN ResNet101 Object Detector

# %%
# Model training directory and config pipeline
model_dir = os.path.join(current_dir, 'training')
pipeline_config_path = 'fasterrcnn_config.config'
# Test training params
print (pipeline_config_path, model_dir, NUM_STEPS)
# Out:
# fasterrcnn_config.config /home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/training 28000

# %%
# Execute training
# !python $current_dir/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path=$pipeline_config_path \
    --model_dir=$model_dir \
    --alsologtostderr \
    --num_train_steps=$NUM_STEPS \
    --num_eval_steps=$NUM_EVAL_STEPS
# Out:
# 2022-12-21 22:33:18.514153: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-21 22:33:19.284785: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2022-12-21 22:33:19.284833: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2022-12-21 22:33:19.284842: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-21 22:33:20.797124: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2022-12-21 22:33:20.797148: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: CMPR01
# 2022-12-21 22:33:20.797154: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: CMPR01
# 2022-12-21 22:33:20.797213: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.161.3
# 2022-12-21 22:33:20.797233: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.91.3
# 2022-12-21 22:33:20.797240: E tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 460.91.3 does not match DSO version 470.161.3 -- cannot find working devices in this configuration
# 2022-12-21 22:33:20.797527: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# W1221 22:33:20.798898 140057406138176 cross_device_ops.py:1387] There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# I1221 22:33:20.810642 140057406138176 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 28000
# I1221 22:33:20.812952 140057406138176 config_util.py:552] Maybe overwriting train_steps: 28000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1221 22:33:20.813034 140057406138176 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1221 22:33:20.840770 140057406138176 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds.tfrecord']
# I1221 22:33:20.846710 140057406138176 dataset_builder.py:162] Reading unweighted datasets: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds.tfrecord']
# I1221 22:33:20.846832 140057406138176 dataset_builder.py:79] Reading record datasets for input file: ['/home/msc1/Desktop/7144COMP/Models/faster_rcnn_resnet101/Birds/train/birds.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I1221 22:33:20.846891 140057406138176 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1221 22:33:20.846940 140057406138176 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W1221 22:33:20.851782 140057406138176 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1221 22:33:20.866701 140057406138176 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1221 22:33:21.276619 140057406138176 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1221 22:33:25.713077 140057406138176 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1221 22:33:28.925994 140057406138176 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-12-21 22:33:30.762543: W tensorflow/core/framework/dataset.cc:769] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1221 22:33:36.021711 140047810557696 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W1221 22:33:40.859714 140047810557696 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W1221 22:33:44.132753 140047810557696 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1176: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1221 22:33:55.125349 140048313857792 deprecation.py:554] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 2.201s
# I1221 22:37:34.921406 140057406138176 model_lib_v2.py:705] Step 100 per-step time 2.201s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.7165007,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.02368744,
#  'Loss/RPNLoss/objectness_loss': 0.36764792,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.107836,
#  'learning_rate': 5.7999998e-05}
# I1221 22:37:34.921617 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.7165007,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.02368744,
#  'Loss/RPNLoss/objectness_loss': 0.36764792,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.107836,
#  'learning_rate': 5.7999998e-05}
# INFO:tensorflow:Step 200 per-step time 1.888s
# I1221 22:40:43.666124 140057406138176 model_lib_v2.py:705] Step 200 per-step time 1.888s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.6720582,
#  'Loss/BoxClassifierLoss/localization_loss': 1.0677336,
#  'Loss/RPNLoss/localization_loss': 0.32345772,
#  'Loss/RPNLoss/objectness_loss': 0.32613474,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.3893843,
#  'learning_rate': 7.6e-05}
# I1221 22:40:43.666311 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.6720582,
#  'Loss/BoxClassifierLoss/localization_loss': 1.0677336,
#  'Loss/RPNLoss/localization_loss': 0.32345772,
#  'Loss/RPNLoss/objectness_loss': 0.32613474,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.3893843,
#  'learning_rate': 7.6e-05}
# INFO:tensorflow:Step 300 per-step time 1.912s
# I1221 22:43:54.837876 140057406138176 model_lib_v2.py:705] Step 300 per-step time 1.912s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.1092244,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.013254315,
#  'Loss/RPNLoss/objectness_loss': 0.10476477,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22724348,
#  'learning_rate': 9.4e-05}
# I1221 22:43:54.838072 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.1092244,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.013254315,
#  'Loss/RPNLoss/objectness_loss': 0.10476477,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22724348,
#  'learning_rate': 9.4e-05}
# INFO:tensorflow:Step 400 per-step time 1.942s
# I1221 22:47:09.079486 140057406138176 model_lib_v2.py:705] Step 400 per-step time 1.942s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.1331932,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.014157755,
#  'Loss/RPNLoss/objectness_loss': 0.11314909,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.26050004,
#  'learning_rate': 0.000112}
# I1221 22:47:09.079690 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.1331932,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.014157755,
#  'Loss/RPNLoss/objectness_loss': 0.11314909,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.26050004,
#  'learning_rate': 0.000112}
# INFO:tensorflow:Step 500 per-step time 1.947s
# I1221 22:50:23.738821 140057406138176 model_lib_v2.py:705] Step 500 per-step time 1.947s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.23223472,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2847478,
#  'Loss/RPNLoss/localization_loss': 0.027336098,
#  'Loss/RPNLoss/objectness_loss': 0.11644665,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.66076535,
#  'learning_rate': 0.00013}
# I1221 22:50:23.739009 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.23223472,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2847478,
#  'Loss/RPNLoss/localization_loss': 0.027336098,
#  'Loss/RPNLoss/objectness_loss': 0.11644665,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.66076535,
#  'learning_rate': 0.00013}
# INFO:tensorflow:Step 600 per-step time 1.951s
# I1221 22:53:38.844310 140057406138176 model_lib_v2.py:705] Step 600 per-step time 1.951s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.07193515,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0066880165,
#  'Loss/RPNLoss/objectness_loss': 0.10065672,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.17927988,
#  'learning_rate': 0.00014799999}
# I1221 22:53:38.844496 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.07193515,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0066880165,
#  'Loss/RPNLoss/objectness_loss': 0.10065672,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.17927988,
#  'learning_rate': 0.00014799999}
# INFO:tensorflow:Step 700 per-step time 1.945s
# I1221 22:56:53.362538 140057406138176 model_lib_v2.py:705] Step 700 per-step time 1.945s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.32787764,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5073639,
#  'Loss/RPNLoss/localization_loss': 0.023896344,
#  'Loss/RPNLoss/objectness_loss': 0.055999666,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.9151375,
#  'learning_rate': 0.000166}
# I1221 22:56:53.362740 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.32787764,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5073639,
#  'Loss/RPNLoss/localization_loss': 0.023896344,
#  'Loss/RPNLoss/objectness_loss': 0.055999666,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.9151375,
#  'learning_rate': 0.000166}
# INFO:tensorflow:Step 800 per-step time 1.941s
# I1221 23:00:07.477953 140057406138176 model_lib_v2.py:705] Step 800 per-step time 1.941s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.16691282,
#  'Loss/BoxClassifierLoss/localization_loss': 0.104066536,
#  'Loss/RPNLoss/localization_loss': 0.02590477,
#  'Loss/RPNLoss/objectness_loss': 0.063083455,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.3599676,
#  'learning_rate': 0.000184}
# I1221 23:00:07.478142 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.16691282,
#  'Loss/BoxClassifierLoss/localization_loss': 0.104066536,
#  'Loss/RPNLoss/localization_loss': 0.02590477,
#  'Loss/RPNLoss/objectness_loss': 0.063083455,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.3599676,
#  'learning_rate': 0.000184}
# INFO:tensorflow:Step 900 per-step time 1.952s
# I1221 23:03:22.630913 140057406138176 model_lib_v2.py:705] Step 900 per-step time 1.952s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.070018284,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.08158827,
#  'Loss/RPNLoss/objectness_loss': 0.07543869,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22704525,
#  'learning_rate': 0.000202}
# I1221 23:03:22.631106 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.070018284,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.08158827,
#  'Loss/RPNLoss/objectness_loss': 0.07543869,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22704525,
#  'learning_rate': 0.000202}
# INFO:tensorflow:Step 1000 per-step time 1.933s
# I1221 23:06:35.932770 140057406138176 model_lib_v2.py:705] Step 1000 per-step time 1.933s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.40287828,
#  'Loss/BoxClassifierLoss/localization_loss': 0.30310285,
#  'Loss/RPNLoss/localization_loss': 0.059883088,
#  'Loss/RPNLoss/objectness_loss': 0.085821375,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.8516856,
#  'learning_rate': 0.00022}
# I1221 23:06:35.932987 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.40287828,
#  'Loss/BoxClassifierLoss/localization_loss': 0.30310285,
#  'Loss/RPNLoss/localization_loss': 0.059883088,
#  'Loss/RPNLoss/objectness_loss': 0.085821375,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.8516856,
#  'learning_rate': 0.00022}
# INFO:tensorflow:Step 1100 per-step time 1.951s
# I1221 23:09:51.000027 140057406138176 model_lib_v2.py:705] Step 1100 per-step time 1.951s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.07083848,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.024961628,
#  'Loss/RPNLoss/objectness_loss': 0.054552402,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.15035251,
#  'learning_rate': 0.000238}
# I1221 23:09:51.000222 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.07083848,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.024961628,
#  'Loss/RPNLoss/objectness_loss': 0.054552402,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.15035251,
#  'learning_rate': 0.000238}
# INFO:tensorflow:Step 1200 per-step time 1.938s
# I1221 23:13:04.784843 140057406138176 model_lib_v2.py:705] Step 1200 per-step time 1.938s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.40367615,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12946533,
#  'Loss/RPNLoss/localization_loss': 0.009324954,
#  'Loss/RPNLoss/objectness_loss': 0.055331882,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.59779835,
#  'learning_rate': 0.000256}
# I1221 23:13:04.785031 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.40367615,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12946533,
#  'Loss/RPNLoss/localization_loss': 0.009324954,
#  'Loss/RPNLoss/objectness_loss': 0.055331882,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.59779835,
#  'learning_rate': 0.000256}
# INFO:tensorflow:Step 1300 per-step time 1.937s
# I1221 23:16:18.504353 140057406138176 model_lib_v2.py:705] Step 1300 per-step time 1.937s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.5035167,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29049036,
#  'Loss/RPNLoss/localization_loss': 0.8704997,
#  'Loss/RPNLoss/objectness_loss': 0.29417637,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.958683,
#  'learning_rate': 0.000274}
# I1221 23:16:18.504543 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.5035167,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29049036,
#  'Loss/RPNLoss/localization_loss': 0.8704997,
#  'Loss/RPNLoss/objectness_loss': 0.29417637,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.958683,
#  'learning_rate': 0.000274}
# INFO:tensorflow:Step 1400 per-step time 1.938s
# I1221 23:19:32.272849 140057406138176 model_lib_v2.py:705] Step 1400 per-step time 1.938s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.17349476,
#  'Loss/BoxClassifierLoss/localization_loss': 0.13192078,
#  'Loss/RPNLoss/localization_loss': 0.010867918,
#  'Loss/RPNLoss/objectness_loss': 0.078841425,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.39512488,
#  'learning_rate': 0.000292}
# I1221 23:19:32.273039 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.17349476,
#  'Loss/BoxClassifierLoss/localization_loss': 0.13192078,
#  'Loss/RPNLoss/localization_loss': 0.010867918,
#  'Loss/RPNLoss/objectness_loss': 0.078841425,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.39512488,
#  'learning_rate': 0.000292}
# INFO:tensorflow:Step 1500 per-step time 1.939s
# I1221 23:22:46.173330 140057406138176 model_lib_v2.py:705] Step 1500 per-step time 1.939s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.38752887,
#  'Loss/BoxClassifierLoss/localization_loss': 0.33070517,
#  'Loss/RPNLoss/localization_loss': 0.11172184,
#  'Loss/RPNLoss/objectness_loss': 0.08849841,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.9184543,
#  'learning_rate': 0.00030999997}
# I1221 23:22:46.173520 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.38752887,
#  'Loss/BoxClassifierLoss/localization_loss': 0.33070517,
#  'Loss/RPNLoss/localization_loss': 0.11172184,
#  'Loss/RPNLoss/objectness_loss': 0.08849841,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.9184543,
#  'learning_rate': 0.00030999997}
# INFO:tensorflow:Step 1600 per-step time 1.929s
# I1221 23:25:59.031046 140057406138176 model_lib_v2.py:705] Step 1600 per-step time 1.929s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.33950043,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12534334,
#  'Loss/RPNLoss/localization_loss': 0.049103197,
#  'Loss/RPNLoss/objectness_loss': 0.02484512,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5387921,
#  'learning_rate': 0.000328}
# I1221 23:25:59.031234 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.33950043,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12534334,
#  'Loss/RPNLoss/localization_loss': 0.049103197,
#  'Loss/RPNLoss/objectness_loss': 0.02484512,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5387921,
#  'learning_rate': 0.000328}
# INFO:tensorflow:Step 1700 per-step time 1.925s
# I1221 23:29:11.556150 140057406138176 model_lib_v2.py:705] Step 1700 per-step time 1.925s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.14772654,
#  'Loss/BoxClassifierLoss/localization_loss': 0.019292386,
#  'Loss/RPNLoss/localization_loss': 0.02246345,
#  'Loss/RPNLoss/objectness_loss': 0.024540482,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.21402285,
#  'learning_rate': 0.00034600002}
# I1221 23:29:11.556360 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.14772654,
#  'Loss/BoxClassifierLoss/localization_loss': 0.019292386,
#  'Loss/RPNLoss/localization_loss': 0.02246345,
#  'Loss/RPNLoss/objectness_loss': 0.024540482,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.21402285,
#  'learning_rate': 0.00034600002}
# INFO:tensorflow:Step 1800 per-step time 1.925s
# I1221 23:32:24.050435 140057406138176 model_lib_v2.py:705] Step 1800 per-step time 1.925s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.6776184,
#  'Loss/BoxClassifierLoss/localization_loss': 0.542938,
#  'Loss/RPNLoss/localization_loss': 1.0136367,
#  'Loss/RPNLoss/objectness_loss': 0.2238608,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.458054,
#  'learning_rate': 0.00036399998}
# I1221 23:32:24.050638 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.6776184,
#  'Loss/BoxClassifierLoss/localization_loss': 0.542938,
#  'Loss/RPNLoss/localization_loss': 1.0136367,
#  'Loss/RPNLoss/objectness_loss': 0.2238608,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.458054,
#  'learning_rate': 0.00036399998}
# INFO:tensorflow:Step 1900 per-step time 1.923s
# I1221 23:35:36.338975 140057406138176 model_lib_v2.py:705] Step 1900 per-step time 1.923s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.2979647,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3255922,
#  'Loss/RPNLoss/localization_loss': 0.024627222,
#  'Loss/RPNLoss/objectness_loss': 0.06110662,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7092907,
#  'learning_rate': 0.000382}
# I1221 23:35:36.339164 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.2979647,
#  'Loss/BoxClassifierLoss/localization_loss': 0.3255922,
#  'Loss/RPNLoss/localization_loss': 0.024627222,
#  'Loss/RPNLoss/objectness_loss': 0.06110662,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7092907,
#  'learning_rate': 0.000382}
# INFO:tensorflow:Step 2000 per-step time 1.926s
# I1221 23:38:48.937575 140057406138176 model_lib_v2.py:705] Step 2000 per-step time 1.926s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.43866825,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07487598,
#  'Loss/RPNLoss/localization_loss': 0.11065012,
#  'Loss/RPNLoss/objectness_loss': 0.06975408,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.69394845,
#  'learning_rate': 0.0004}
# I1221 23:38:48.937823 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.43866825,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07487598,
#  'Loss/RPNLoss/localization_loss': 0.11065012,
#  'Loss/RPNLoss/objectness_loss': 0.06975408,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.69394845,
#  'learning_rate': 0.0004}
# INFO:tensorflow:Step 2100 per-step time 1.944s
# I1221 23:42:03.341228 140057406138176 model_lib_v2.py:705] Step 2100 per-step time 1.944s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.48893446,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5486248,
#  'Loss/RPNLoss/localization_loss': 0.03152921,
#  'Loss/RPNLoss/objectness_loss': 0.06570724,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.1347957,
#  'learning_rate': 0.00039999897}
# I1221 23:42:03.341424 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.48893446,
#  'Loss/BoxClassifierLoss/localization_loss': 0.5486248,
#  'Loss/RPNLoss/localization_loss': 0.03152921,
#  'Loss/RPNLoss/objectness_loss': 0.06570724,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.1347957,
#  'learning_rate': 0.00039999897}
# INFO:tensorflow:Step 2200 per-step time 1.930s
# I1221 23:45:16.380395 140057406138176 model_lib_v2.py:705] Step 2200 per-step time 1.930s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.09272288,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.07397568,
#  'Loss/RPNLoss/objectness_loss': 0.043375045,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2100736,
#  'learning_rate': 0.0003999959}
# I1221 23:45:16.380583 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.09272288,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.07397568,
#  'Loss/RPNLoss/objectness_loss': 0.043375045,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2100736,
#  'learning_rate': 0.0003999959}
# INFO:tensorflow:Step 2300 per-step time 1.927s
# I1221 23:48:29.095499 140057406138176 model_lib_v2.py:705] Step 2300 per-step time 1.927s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.13574794,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.382737,
#  'Loss/RPNLoss/objectness_loss': 0.0935959,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6120808,
#  'learning_rate': 0.00039999073}
# I1221 23:48:29.095693 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.13574794,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.382737,
#  'Loss/RPNLoss/objectness_loss': 0.0935959,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6120808,
#  'learning_rate': 0.00039999073}
# INFO:tensorflow:Step 2400 per-step time 1.926s
# I1221 23:51:41.732311 140057406138176 model_lib_v2.py:705] Step 2400 per-step time 1.926s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.10518557,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.021724636,
#  'Loss/RPNLoss/objectness_loss': 0.05516368,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.18207389,
#  'learning_rate': 0.00039998355}
# I1221 23:51:41.732496 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.10518557,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.021724636,
#  'Loss/RPNLoss/objectness_loss': 0.05516368,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.18207389,
#  'learning_rate': 0.00039998355}
# INFO:tensorflow:Step 2500 per-step time 1.924s
# I1221 23:54:54.127668 140057406138176 model_lib_v2.py:705] Step 2500 per-step time 1.924s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.34999454,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07699711,
#  'Loss/RPNLoss/localization_loss': 0.6594715,
#  'Loss/RPNLoss/objectness_loss': 0.03836011,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.1248233,
#  'learning_rate': 0.0003999743}
# I1221 23:54:54.127858 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.34999454,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07699711,
#  'Loss/RPNLoss/localization_loss': 0.6594715,
#  'Loss/RPNLoss/objectness_loss': 0.03836011,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.1248233,
#  'learning_rate': 0.0003999743}
# INFO:tensorflow:Step 2600 per-step time 1.921s
# I1221 23:58:06.257248 140057406138176 model_lib_v2.py:705] Step 2600 per-step time 1.921s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.4728409,
#  'Loss/BoxClassifierLoss/localization_loss': 0.6243404,
#  'Loss/RPNLoss/localization_loss': 0.008056081,
#  'Loss/RPNLoss/objectness_loss': 0.041072614,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.14631,
#  'learning_rate': 0.000399963}
# I1221 23:58:06.257437 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.4728409,
#  'Loss/BoxClassifierLoss/localization_loss': 0.6243404,
#  'Loss/RPNLoss/localization_loss': 0.008056081,
#  'Loss/RPNLoss/objectness_loss': 0.041072614,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.14631,
#  'learning_rate': 0.000399963}
# INFO:tensorflow:Step 2700 per-step time 1.927s
# I1222 00:01:18.919255 140057406138176 model_lib_v2.py:705] Step 2700 per-step time 1.927s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.29106724,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06221366,
#  'Loss/RPNLoss/localization_loss': 0.04957143,
#  'Loss/RPNLoss/objectness_loss': 0.013534724,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.41638705,
#  'learning_rate': 0.00039994964}
# I1222 00:01:18.919443 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.29106724,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06221366,
#  'Loss/RPNLoss/localization_loss': 0.04957143,
#  'Loss/RPNLoss/objectness_loss': 0.013534724,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.41638705,
#  'learning_rate': 0.00039994964}
# INFO:tensorflow:Step 2800 per-step time 1.926s
# I1222 00:04:31.542105 140057406138176 model_lib_v2.py:705] Step 2800 per-step time 1.926s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.20774412,
#  'Loss/BoxClassifierLoss/localization_loss': 0.056214675,
#  'Loss/RPNLoss/localization_loss': 0.010962117,
#  'Loss/RPNLoss/objectness_loss': 0.016365994,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2912869,
#  'learning_rate': 0.00039993424}
# I1222 00:04:31.542292 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.20774412,
#  'Loss/BoxClassifierLoss/localization_loss': 0.056214675,
#  'Loss/RPNLoss/localization_loss': 0.010962117,
#  'Loss/RPNLoss/objectness_loss': 0.016365994,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.2912869,
#  'learning_rate': 0.00039993424}
# INFO:tensorflow:Step 2900 per-step time 1.925s
# I1222 00:07:44.009018 140057406138176 model_lib_v2.py:705] Step 2900 per-step time 1.925s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.13405818,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12079214,
#  'Loss/RPNLoss/localization_loss': 0.0060617006,
#  'Loss/RPNLoss/objectness_loss': 0.019528005,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.28044,
#  'learning_rate': 0.00039991675}
# I1222 00:07:44.009206 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.13405818,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12079214,
#  'Loss/RPNLoss/localization_loss': 0.0060617006,
#  'Loss/RPNLoss/objectness_loss': 0.019528005,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.28044,
#  'learning_rate': 0.00039991675}
# INFO:tensorflow:Step 3000 per-step time 1.930s
# I1222 00:10:57.034686 140057406138176 model_lib_v2.py:705] Step 3000 per-step time 1.930s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.23751988,
#  'Loss/BoxClassifierLoss/localization_loss': 0.04081313,
#  'Loss/RPNLoss/localization_loss': 0.016589861,
#  'Loss/RPNLoss/objectness_loss': 0.021256909,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.31617975,
#  'learning_rate': 0.00039989722}
# I1222 00:10:57.034873 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.23751988,
#  'Loss/BoxClassifierLoss/localization_loss': 0.04081313,
#  'Loss/RPNLoss/localization_loss': 0.016589861,
#  'Loss/RPNLoss/objectness_loss': 0.021256909,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.31617975,
#  'learning_rate': 0.00039989722}
# INFO:tensorflow:Step 3100 per-step time 1.939s
# I1222 00:14:10.982498 140057406138176 model_lib_v2.py:705] Step 3100 per-step time 1.939s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.32002178,
#  'Loss/BoxClassifierLoss/localization_loss': 0.11102916,
#  'Loss/RPNLoss/localization_loss': 0.014027064,
#  'Loss/RPNLoss/objectness_loss': 0.12158166,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5666597,
#  'learning_rate': 0.00039987566}
# I1222 00:14:10.982692 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.32002178,
#  'Loss/BoxClassifierLoss/localization_loss': 0.11102916,
#  'Loss/RPNLoss/localization_loss': 0.014027064,
#  'Loss/RPNLoss/objectness_loss': 0.12158166,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.5666597,
#  'learning_rate': 0.00039987566}
# INFO:tensorflow:Step 3200 per-step time 1.931s
# I1222 00:17:24.042536 140057406138176 model_lib_v2.py:705] Step 3200 per-step time 1.931s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.09519531,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.022881266,
#  'Loss/RPNLoss/objectness_loss': 0.030008132,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.14808472,
#  'learning_rate': 0.00039985203}
# I1222 00:17:24.042723 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.09519531,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.022881266,
#  'Loss/RPNLoss/objectness_loss': 0.030008132,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.14808472,
#  'learning_rate': 0.00039985203}
# INFO:tensorflow:Step 3300 per-step time 1.925s
# I1222 00:20:36.578366 140057406138176 model_lib_v2.py:705] Step 3300 per-step time 1.925s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.34970784,
#  'Loss/BoxClassifierLoss/localization_loss': 0.21461697,
#  'Loss/RPNLoss/localization_loss': 0.20615502,
#  'Loss/RPNLoss/objectness_loss': 0.06505274,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.83553255,
#  'learning_rate': 0.00039982633}
# I1222 00:20:36.578555 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.34970784,
#  'Loss/BoxClassifierLoss/localization_loss': 0.21461697,
#  'Loss/RPNLoss/localization_loss': 0.20615502,
#  'Loss/RPNLoss/objectness_loss': 0.06505274,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.83553255,
#  'learning_rate': 0.00039982633}
# INFO:tensorflow:Step 3400 per-step time 1.926s
# I1222 00:23:49.164417 140057406138176 model_lib_v2.py:705] Step 3400 per-step time 1.926s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.67809844,
#  'Loss/BoxClassifierLoss/localization_loss': 0.55196816,
#  'Loss/RPNLoss/localization_loss': 0.024208635,
#  'Loss/RPNLoss/objectness_loss': 0.014239167,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.2685144,
#  'learning_rate': 0.0003997986}
# I1222 00:23:49.164603 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.67809844,
#  'Loss/BoxClassifierLoss/localization_loss': 0.55196816,
#  'Loss/RPNLoss/localization_loss': 0.024208635,
#  'Loss/RPNLoss/objectness_loss': 0.014239167,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.2685144,
#  'learning_rate': 0.0003997986}
# INFO:tensorflow:Step 3500 per-step time 1.927s
# I1222 00:27:01.846428 140057406138176 model_lib_v2.py:705] Step 3500 per-step time 1.927s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.15941858,
#  'Loss/BoxClassifierLoss/localization_loss': 0.08338295,
#  'Loss/RPNLoss/localization_loss': 0.018726075,
#  'Loss/RPNLoss/objectness_loss': 0.021330852,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.28285846,
#  'learning_rate': 0.00039976882}
# I1222 00:27:01.846615 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.15941858,
#  'Loss/BoxClassifierLoss/localization_loss': 0.08338295,
#  'Loss/RPNLoss/localization_loss': 0.018726075,
#  'Loss/RPNLoss/objectness_loss': 0.021330852,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.28285846,
#  'learning_rate': 0.00039976882}
# INFO:tensorflow:Step 3600 per-step time 1.922s
# I1222 00:30:14.060185 140057406138176 model_lib_v2.py:705] Step 3600 per-step time 1.922s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.13267867,
#  'Loss/BoxClassifierLoss/localization_loss': 0.026392043,
#  'Loss/RPNLoss/localization_loss': 0.013003904,
#  'Loss/RPNLoss/objectness_loss': 0.02011352,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.19218814,
#  'learning_rate': 0.00039973698}
# I1222 00:30:14.060380 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.13267867,
#  'Loss/BoxClassifierLoss/localization_loss': 0.026392043,
#  'Loss/RPNLoss/localization_loss': 0.013003904,
#  'Loss/RPNLoss/objectness_loss': 0.02011352,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.19218814,
#  'learning_rate': 0.00039973698}
# INFO:tensorflow:Step 3700 per-step time 1.928s
# I1222 00:33:26.812920 140057406138176 model_lib_v2.py:705] Step 3700 per-step time 1.928s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.28982353,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07936447,
#  'Loss/RPNLoss/localization_loss': 0.02712196,
#  'Loss/RPNLoss/objectness_loss': 0.010314896,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.40662485,
#  'learning_rate': 0.00039970307}
# I1222 00:33:26.813108 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.28982353,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07936447,
#  'Loss/RPNLoss/localization_loss': 0.02712196,
#  'Loss/RPNLoss/objectness_loss': 0.010314896,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.40662485,
#  'learning_rate': 0.00039970307}
# INFO:tensorflow:Step 3800 per-step time 1.921s
# I1222 00:36:38.952585 140057406138176 model_lib_v2.py:705] Step 3800 per-step time 1.921s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.07474844,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06460253,
#  'Loss/RPNLoss/localization_loss': 0.0105622085,
#  'Loss/RPNLoss/objectness_loss': 0.018320482,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.16823366,
#  'learning_rate': 0.0003996671}
# I1222 00:36:38.952776 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.07474844,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06460253,
#  'Loss/RPNLoss/localization_loss': 0.0105622085,
#  'Loss/RPNLoss/objectness_loss': 0.018320482,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.16823366,
#  'learning_rate': 0.0003996671}
# INFO:tensorflow:Step 3900 per-step time 1.928s
# I1222 00:39:51.742109 140057406138176 model_lib_v2.py:705] Step 3900 per-step time 1.928s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.40529078,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29679725,
#  'Loss/RPNLoss/localization_loss': 0.022331618,
#  'Loss/RPNLoss/objectness_loss': 0.06107547,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.78549516,
#  'learning_rate': 0.00039962912}
# I1222 00:39:51.742292 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.40529078,
#  'Loss/BoxClassifierLoss/localization_loss': 0.29679725,
#  'Loss/RPNLoss/localization_loss': 0.022331618,
#  'Loss/RPNLoss/objectness_loss': 0.06107547,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.78549516,
#  'learning_rate': 0.00039962912}
# INFO:tensorflow:Step 4000 per-step time 1.930s
# I1222 00:43:04.718868 140057406138176 model_lib_v2.py:705] Step 4000 per-step time 1.930s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.5004599,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2214015,
#  'Loss/RPNLoss/localization_loss': 1.0897088,
#  'Loss/RPNLoss/objectness_loss': 0.18427655,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.9958467,
#  'learning_rate': 0.00039958904}
# I1222 00:43:04.719051 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.5004599,
#  'Loss/BoxClassifierLoss/localization_loss': 0.2214015,
#  'Loss/RPNLoss/localization_loss': 1.0897088,
#  'Loss/RPNLoss/objectness_loss': 0.18427655,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.9958467,
#  'learning_rate': 0.00039958904}
# INFO:tensorflow:Step 4100 per-step time 1.936s
# I1222 00:46:18.326394 140057406138176 model_lib_v2.py:705] Step 4100 per-step time 1.936s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.27422202,
#  'Loss/BoxClassifierLoss/localization_loss': 0.11611998,
#  'Loss/RPNLoss/localization_loss': 0.020829799,
#  'Loss/RPNLoss/objectness_loss': 0.025765058,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.43693686,
#  'learning_rate': 0.00039954696}
# I1222 00:46:18.326588 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.27422202,
#  'Loss/BoxClassifierLoss/localization_loss': 0.11611998,
#  'Loss/RPNLoss/localization_loss': 0.020829799,
#  'Loss/RPNLoss/objectness_loss': 0.025765058,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.43693686,
#  'learning_rate': 0.00039954696}
# INFO:tensorflow:Step 4200 per-step time 1.921s
# I1222 00:49:30.399140 140057406138176 model_lib_v2.py:705] Step 4200 per-step time 1.921s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.3630948,
#  'Loss/BoxClassifierLoss/localization_loss': 0.04442383,
#  'Loss/RPNLoss/localization_loss': 0.03301487,
#  'Loss/RPNLoss/objectness_loss': 0.012813967,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.45334747,
#  'learning_rate': 0.0003995028}
# I1222 00:49:30.399324 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.3630948,
#  'Loss/BoxClassifierLoss/localization_loss': 0.04442383,
#  'Loss/RPNLoss/localization_loss': 0.03301487,
#  'Loss/RPNLoss/objectness_loss': 0.012813967,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.45334747,
#  'learning_rate': 0.0003995028}
# INFO:tensorflow:Step 4300 per-step time 1.928s
# I1222 00:52:43.151452 140057406138176 model_lib_v2.py:705] Step 4300 per-step time 1.928s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.040579475,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.030629177,
#  'Loss/RPNLoss/objectness_loss': 0.013139001,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.08434765,
#  'learning_rate': 0.00039945662}
# I1222 00:52:43.151640 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.040579475,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.030629177,
#  'Loss/RPNLoss/objectness_loss': 0.013139001,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.08434765,
#  'learning_rate': 0.00039945662}
# INFO:tensorflow:Step 4400 per-step time 1.926s
# I1222 00:55:55.726796 140057406138176 model_lib_v2.py:705] Step 4400 per-step time 1.926s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.07656576,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.019546157,
#  'Loss/RPNLoss/objectness_loss': 0.05563696,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.15174887,
#  'learning_rate': 0.00039940837}
# I1222 00:55:55.726979 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.07656576,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.019546157,
#  'Loss/RPNLoss/objectness_loss': 0.05563696,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.15174887,
# ...
#  'Loss/RPNLoss/objectness_loss': 0.0076722573,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.09627625,
#  'learning_rate': 0.00034322307}
# INFO:tensorflow:Step 26200 per-step time 1.924s
# I1222 12:33:44.020109 140057406138176 model_lib_v2.py:705] Step 26200 per-step time 1.924s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.03483602,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07162593,
#  'Loss/RPNLoss/localization_loss': 0.50659454,
#  'Loss/RPNLoss/objectness_loss': 0.015717274,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.62877375,
#  'learning_rate': 0.00034277485}
# I1222 12:33:44.020307 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.03483602,
#  'Loss/BoxClassifierLoss/localization_loss': 0.07162593,
#  'Loss/RPNLoss/localization_loss': 0.50659454,
#  'Loss/RPNLoss/objectness_loss': 0.015717274,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.62877375,
#  'learning_rate': 0.00034277485}
# INFO:tensorflow:Step 26300 per-step time 1.933s
# I1222 12:36:57.316121 140057406138176 model_lib_v2.py:705] Step 26300 per-step time 1.933s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.12879252,
#  'Loss/BoxClassifierLoss/localization_loss': 0.17843832,
#  'Loss/RPNLoss/localization_loss': 0.11876917,
#  'Loss/RPNLoss/objectness_loss': 0.0051303245,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.43113032,
#  'learning_rate': 0.00034232516}
# I1222 12:36:57.316324 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.12879252,
#  'Loss/BoxClassifierLoss/localization_loss': 0.17843832,
#  'Loss/RPNLoss/localization_loss': 0.11876917,
#  'Loss/RPNLoss/objectness_loss': 0.0051303245,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.43113032,
#  'learning_rate': 0.00034232516}
# INFO:tensorflow:Step 26400 per-step time 1.910s
# I1222 12:40:08.311827 140057406138176 model_lib_v2.py:705] Step 26400 per-step time 1.910s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.11114094,
#  'Loss/BoxClassifierLoss/localization_loss': 0.060324825,
#  'Loss/RPNLoss/localization_loss': 0.016799405,
#  'Loss/RPNLoss/objectness_loss': 0.056678563,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.24494372,
#  'learning_rate': 0.00034187397}
# I1222 12:40:08.312022 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.11114094,
#  'Loss/BoxClassifierLoss/localization_loss': 0.060324825,
#  'Loss/RPNLoss/localization_loss': 0.016799405,
#  'Loss/RPNLoss/objectness_loss': 0.056678563,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.24494372,
#  'learning_rate': 0.00034187397}
# INFO:tensorflow:Step 26500 per-step time 1.914s
# I1222 12:43:19.702746 140057406138176 model_lib_v2.py:705] Step 26500 per-step time 1.914s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.13485494,
#  'Loss/BoxClassifierLoss/localization_loss': 0.31957,
#  'Loss/RPNLoss/localization_loss': 0.011148299,
#  'Loss/RPNLoss/objectness_loss': 0.0034585176,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.46903178,
#  'learning_rate': 0.00034142137}
# I1222 12:43:19.702935 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.13485494,
#  'Loss/BoxClassifierLoss/localization_loss': 0.31957,
#  'Loss/RPNLoss/localization_loss': 0.011148299,
#  'Loss/RPNLoss/objectness_loss': 0.0034585176,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.46903178,
#  'learning_rate': 0.00034142137}
# INFO:tensorflow:Step 26600 per-step time 1.931s
# I1222 12:46:32.834373 140057406138176 model_lib_v2.py:705] Step 26600 per-step time 1.931s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.51487565,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03706407,
#  'Loss/RPNLoss/localization_loss': 0.21507826,
#  'Loss/RPNLoss/objectness_loss': 0.011126116,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7781441,
#  'learning_rate': 0.00034096726}
# I1222 12:46:32.834561 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.51487565,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03706407,
#  'Loss/RPNLoss/localization_loss': 0.21507826,
#  'Loss/RPNLoss/objectness_loss': 0.011126116,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7781441,
#  'learning_rate': 0.00034096726}
# INFO:tensorflow:Step 26700 per-step time 1.937s
# I1222 12:49:46.559836 140057406138176 model_lib_v2.py:705] Step 26700 per-step time 1.937s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0692394,
#  'Loss/BoxClassifierLoss/localization_loss': 0.04418522,
#  'Loss/RPNLoss/localization_loss': 0.035643496,
#  'Loss/RPNLoss/objectness_loss': 0.0025789342,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.15164706,
#  'learning_rate': 0.00034051173}
# I1222 12:49:46.560024 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.0692394,
#  'Loss/BoxClassifierLoss/localization_loss': 0.04418522,
#  'Loss/RPNLoss/localization_loss': 0.035643496,
#  'Loss/RPNLoss/objectness_loss': 0.0025789342,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.15164706,
#  'learning_rate': 0.00034051173}
# INFO:tensorflow:Step 26800 per-step time 1.894s
# I1222 12:52:55.936685 140057406138176 model_lib_v2.py:705] Step 26800 per-step time 1.894s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.021744434,
#  'Loss/BoxClassifierLoss/localization_loss': 0.055302747,
#  'Loss/RPNLoss/localization_loss': 0.0030798188,
#  'Loss/RPNLoss/objectness_loss': 0.0036154778,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.08374247,
#  'learning_rate': 0.00034005474}
# I1222 12:52:55.936873 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.021744434,
#  'Loss/BoxClassifierLoss/localization_loss': 0.055302747,
#  'Loss/RPNLoss/localization_loss': 0.0030798188,
#  'Loss/RPNLoss/objectness_loss': 0.0036154778,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.08374247,
#  'learning_rate': 0.00034005474}
# INFO:tensorflow:Step 26900 per-step time 1.905s
# I1222 12:56:06.431908 140057406138176 model_lib_v2.py:705] Step 26900 per-step time 1.905s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.1181429,
#  'Loss/BoxClassifierLoss/localization_loss': 0.09374484,
#  'Loss/RPNLoss/localization_loss': 0.009949464,
#  'Loss/RPNLoss/objectness_loss': 0.0016975424,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22353475,
#  'learning_rate': 0.00033959636}
# I1222 12:56:06.432119 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.1181429,
#  'Loss/BoxClassifierLoss/localization_loss': 0.09374484,
#  'Loss/RPNLoss/localization_loss': 0.009949464,
#  'Loss/RPNLoss/objectness_loss': 0.0016975424,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22353475,
#  'learning_rate': 0.00033959636}
# INFO:tensorflow:Step 27000 per-step time 1.945s
# I1222 12:59:20.883615 140057406138176 model_lib_v2.py:705] Step 27000 per-step time 1.945s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.07619415,
#  'Loss/BoxClassifierLoss/localization_loss': 0.075267926,
#  'Loss/RPNLoss/localization_loss': 0.009543829,
#  'Loss/RPNLoss/objectness_loss': 0.0065310476,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.16753694,
#  'learning_rate': 0.0003391365}
# I1222 12:59:20.883807 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.07619415,
#  'Loss/BoxClassifierLoss/localization_loss': 0.075267926,
#  'Loss/RPNLoss/localization_loss': 0.009543829,
#  'Loss/RPNLoss/objectness_loss': 0.0065310476,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.16753694,
#  'learning_rate': 0.0003391365}
# INFO:tensorflow:Step 27100 per-step time 1.943s
# I1222 13:02:35.219949 140057406138176 model_lib_v2.py:705] Step 27100 per-step time 1.943s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.06199842,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15878491,
#  'Loss/RPNLoss/localization_loss': 0.004407564,
#  'Loss/RPNLoss/objectness_loss': 0.0018206397,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22701155,
#  'learning_rate': 0.0003386752}
# I1222 13:02:35.220143 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.06199842,
#  'Loss/BoxClassifierLoss/localization_loss': 0.15878491,
#  'Loss/RPNLoss/localization_loss': 0.004407564,
#  'Loss/RPNLoss/objectness_loss': 0.0018206397,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.22701155,
#  'learning_rate': 0.0003386752}
# INFO:tensorflow:Step 27200 per-step time 1.932s
# I1222 13:05:48.468403 140057406138176 model_lib_v2.py:705] Step 27200 per-step time 1.932s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.21787609,
#  'Loss/BoxClassifierLoss/localization_loss': 0.31394142,
#  'Loss/RPNLoss/localization_loss': 0.08385237,
#  'Loss/RPNLoss/objectness_loss': 0.0038672115,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6195371,
#  'learning_rate': 0.00033821253}
# I1222 13:05:48.468593 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.21787609,
#  'Loss/BoxClassifierLoss/localization_loss': 0.31394142,
#  'Loss/RPNLoss/localization_loss': 0.08385237,
#  'Loss/RPNLoss/objectness_loss': 0.0038672115,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.6195371,
#  'learning_rate': 0.00033821253}
# INFO:tensorflow:Step 27300 per-step time 1.918s
# I1222 13:09:00.313210 140057406138176 model_lib_v2.py:705] Step 27300 per-step time 1.918s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.10087629,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06431215,
#  'Loss/RPNLoss/localization_loss': 0.0006325036,
#  'Loss/RPNLoss/objectness_loss': 0.000868925,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.16668987,
#  'learning_rate': 0.00033774838}
# I1222 13:09:00.313409 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.10087629,
#  'Loss/BoxClassifierLoss/localization_loss': 0.06431215,
#  'Loss/RPNLoss/localization_loss': 0.0006325036,
#  'Loss/RPNLoss/objectness_loss': 0.000868925,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.16668987,
#  'learning_rate': 0.00033774838}
# INFO:tensorflow:Step 27400 per-step time 1.928s
# I1222 13:12:13.078875 140057406138176 model_lib_v2.py:705] Step 27400 per-step time 1.928s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.048791766,
#  'Loss/BoxClassifierLoss/localization_loss': 0.022029597,
#  'Loss/RPNLoss/localization_loss': 0.0005948173,
#  'Loss/RPNLoss/objectness_loss': 0.0034162486,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.074832425,
#  'learning_rate': 0.00033728287}
# I1222 13:12:13.079064 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.048791766,
#  'Loss/BoxClassifierLoss/localization_loss': 0.022029597,
#  'Loss/RPNLoss/localization_loss': 0.0005948173,
#  'Loss/RPNLoss/objectness_loss': 0.0034162486,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.074832425,
#  'learning_rate': 0.00033728287}
# INFO:tensorflow:Step 27500 per-step time 1.954s
# I1222 13:15:28.476646 140057406138176 model_lib_v2.py:705] Step 27500 per-step time 1.954s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.025245067,
#  'Loss/BoxClassifierLoss/localization_loss': 0.09560767,
#  'Loss/RPNLoss/localization_loss': 0.004140845,
#  'Loss/RPNLoss/objectness_loss': 0.002377025,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.12737061,
#  'learning_rate': 0.0003368159}
# I1222 13:15:28.476848 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.025245067,
#  'Loss/BoxClassifierLoss/localization_loss': 0.09560767,
#  'Loss/RPNLoss/localization_loss': 0.004140845,
#  'Loss/RPNLoss/objectness_loss': 0.002377025,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.12737061,
#  'learning_rate': 0.0003368159}
# INFO:tensorflow:Step 27600 per-step time 1.947s
# I1222 13:18:43.161965 140057406138176 model_lib_v2.py:705] Step 27600 per-step time 1.947s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.049113855,
#  'Loss/BoxClassifierLoss/localization_loss': 0.021244727,
#  'Loss/RPNLoss/localization_loss': 0.0026444404,
#  'Loss/RPNLoss/objectness_loss': 0.0021949117,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.075197935,
#  'learning_rate': 0.00033634756}
# I1222 13:18:43.162156 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.049113855,
#  'Loss/BoxClassifierLoss/localization_loss': 0.021244727,
#  'Loss/RPNLoss/localization_loss': 0.0026444404,
#  'Loss/RPNLoss/objectness_loss': 0.0021949117,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.075197935,
#  'learning_rate': 0.00033634756}
# INFO:tensorflow:Step 27700 per-step time 1.922s
# I1222 13:21:55.384139 140057406138176 model_lib_v2.py:705] Step 27700 per-step time 1.922s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.049468696,
#  'Loss/BoxClassifierLoss/localization_loss': 0.09239574,
#  'Loss/RPNLoss/localization_loss': 0.0031897672,
#  'Loss/RPNLoss/objectness_loss': 0.0033906994,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.1484449,
#  'learning_rate': 0.0003358778}
# I1222 13:21:55.384335 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.049468696,
#  'Loss/BoxClassifierLoss/localization_loss': 0.09239574,
#  'Loss/RPNLoss/localization_loss': 0.0031897672,
#  'Loss/RPNLoss/objectness_loss': 0.0033906994,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.1484449,
#  'learning_rate': 0.0003358778}
# INFO:tensorflow:Step 27800 per-step time 1.900s
# I1222 13:25:05.371576 140057406138176 model_lib_v2.py:705] Step 27800 per-step time 1.900s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.0445793,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03401262,
#  'Loss/RPNLoss/localization_loss': 0.04206396,
#  'Loss/RPNLoss/objectness_loss': 0.0060903556,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.12674624,
#  'learning_rate': 0.00033540663}
# I1222 13:25:05.371764 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.0445793,
#  'Loss/BoxClassifierLoss/localization_loss': 0.03401262,
#  'Loss/RPNLoss/localization_loss': 0.04206396,
#  'Loss/RPNLoss/objectness_loss': 0.0060903556,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.12674624,
#  'learning_rate': 0.00033540663}
# INFO:tensorflow:Step 27900 per-step time 1.909s
# I1222 13:28:16.277135 140057406138176 model_lib_v2.py:705] Step 27900 per-step time 1.909s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.05549556,
#  'Loss/BoxClassifierLoss/localization_loss': 0.05879899,
#  'Loss/RPNLoss/localization_loss': 0.010989514,
#  'Loss/RPNLoss/objectness_loss': 0.012984726,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.1382688,
#  'learning_rate': 0.0003349341}
# I1222 13:28:16.277322 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.05549556,
#  'Loss/BoxClassifierLoss/localization_loss': 0.05879899,
#  'Loss/RPNLoss/localization_loss': 0.010989514,
#  'Loss/RPNLoss/objectness_loss': 0.012984726,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.1382688,
#  'learning_rate': 0.0003349341}
# INFO:tensorflow:Step 28000 per-step time 1.921s
# I1222 13:31:28.337023 140057406138176 model_lib_v2.py:705] Step 28000 per-step time 1.921s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.04139775,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12969077,
#  'Loss/RPNLoss/localization_loss': 0.004470203,
#  'Loss/RPNLoss/objectness_loss': 0.0028878995,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.17844662,
#  'learning_rate': 0.00033446014}
# I1222 13:31:28.337214 140057406138176 model_lib_v2.py:708] {'Loss/BoxClassifierLoss/classification_loss': 0.04139775,
#  'Loss/BoxClassifierLoss/localization_loss': 0.12969077,
#  'Loss/RPNLoss/localization_loss': 0.004470203,
#  'Loss/RPNLoss/objectness_loss': 0.0028878995,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.17844662,
#  'learning_rate': 0.00033446014}

# %% [markdown]
# ### Export our OD inference graph

# %% [markdown]
# - Graphs are data structures that contain a set of tf.Operation objects, which represent units of computation; and tf.Tensor objects, which represent the units of data that flow between operations.
#
# - Graphs are defined in a tf.Graph context. Since these graphs are data structures, they can be saved, run, and restored all without the original Python code.
#
# - Here we will save our OD inference graph files in **fasterrcnn_inference_graph/saved_model** directory

# %%
output_directory = 'fasterrcnn_inference_graph'

# !python $current_dir/models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir $model_dir \
    --output_directory $output_directory \
    --pipeline_config_path $pipeline_config_path
# Out:
# 2022-12-22 13:32:16.408113: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-22 13:32:17.489770: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2022-12-22 13:32:17.489831: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64
# 2022-12-22 13:32:17.489840: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-12-22 13:32:19.437146: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2022-12-22 13:32:19.437174: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: CMPR01
# 2022-12-22 13:32:19.437182: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: CMPR01
# 2022-12-22 13:32:19.437421: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 470.161.3
# 2022-12-22 13:32:19.437442: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 460.91.3
# 2022-12-22 13:32:19.437449: E tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 460.91.3 does not match DSO version 470.161.3 -- cannot find working devices in this configuration
# 2022-12-22 13:32:19.458282: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W1222 13:32:19.519686 139664209377088 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1222 13:32:19.584636 139664209377088 deprecation.py:623] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1222 13:32:25.353399 139664209377088 convolutional_keras_box_predictor.py:152] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W1222 13:32:30.621240 139664209377088 deprecation.py:350] From /home/msc1/anaconda3/envs/tf_gpu/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:459: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x7f055cbb9cd0>, because it is not built.
# W1222 13:32:39.359387 139664209377088 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.faster_rcnn_meta_arch.FasterRCNNMetaArch object at 0x7f055cbb9cd0>, because it is not built.
# W1222 13:32:56.879775 139664209377088 save.py:271] Found untraced functions such as FirstStageBoxPredictor_layer_call_fn, FirstStageBoxPredictor_layer_call_and_return_conditional_losses, mask_rcnn_keras_box_predictor_layer_call_fn, mask_rcnn_keras_box_predictor_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op while saving (showing 5 of 135). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: fasterrcnn_inference_graph/saved_model/assets
# I1222 13:33:03.000894 139664209377088 builder_impl.py:797] Assets written to: fasterrcnn_inference_graph/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to fasterrcnn_inference_graph/pipeline.config
# I1222 13:33:04.188942 139664209377088 config_util.py:253] Writing pipeline config file to fasterrcnn_inference_graph/pipeline.config

# %% [markdown]
# #### saved_model.pb file (fasterrcnn_inference_graph/saved_model.saved_model.pb)
# .pb stands for Protocol Buffers, it is a language-neutral, platform-neutral extensible mechanism for serializing structured data (Our TF Graph). It is widely used in model deployment, such as fast inference tool TensorRT.
#
# This file is loaded along with its dependencies by TensorFlow using tf.saved_model.load to make inferences (see deployment part 4).
